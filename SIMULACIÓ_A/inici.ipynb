# %% [markdown]
# <a href="https://colab.research.google.com/github/laura314159265/poly/blob/main/SIMULACI%C3%93_A/inici.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Volem saber quanta energia arriba a la Terra
K= 1361 # Constant solar
N= 9 # Nombre fix de panells solars
A_i= 2 # Àrea de cada panell (m^2)
A_tot=A_i*N
P= 400 # Electricitat que emet cada panell (W)
I_min=1000 # Irradiànica PERPENDICULAR mínima que té per crear 400W

# La llista on ficarem la cosa aquesta
I=[1000, 1000, 1000]

P_tot=0
for i in I:
  if i>=I_min:
    P_tot=P_tot+400

print(P_tot)

# from google.colab import files
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib.lines import Line2D


# uploaded = files.upload()
# file_path = '/content/dades_irradiancia.csv'
# data = pd.read_csv(file_path)
# print(data)
# Out:
# 1200
