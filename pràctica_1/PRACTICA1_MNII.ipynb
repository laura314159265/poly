# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x):
  return np.e**x-3*x


a= 1
b= 2
x= 0

print(f(a),f(b))
#f(a)<0 i f(b)>0

while True:
  x= (a+b)/2
  if f(x)<0:
    a=x
  elif f(x)>0:
    b=x
  elif f(x)==0:
    print(f"la sol és: {x}")
    break
  else:
    print("labubu")

print(x, f(x))

lon= np.linspace(0,10,1000)

plt.plot(lon, f(lon))

plt.show()
# Out:
# -0.2817181715409549 1.3890560989306495
# la sol és: 1.5121345516578426
# 1.5121345516578426 0.0
