# %% [markdown]
# <a href="https://colab.research.google.com/github/laura314159265/poly/blob/main/PR%C3%80CTIA_GUIADA/exemple_zoom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

fig1, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel("Temps (s)")
ax1.set_ylabel("Temperatura (°C)")
ax1.set_title("Evolució de la temperatura a la barra d'alumini de ∅=5,1 cm")
ax1.grid(True)
ax1.plot(df["Temps (s)"], df["t.gran(0cm)"], label="d=0 cm", color='#6904bd')
ax1.vlines(90,68,85.7,color='k',linestyle=":")

# ZOOM en axes[0]
axins1 = inset_axes(
    ax1,
    width="60%",
    height="38%",
    bbox_to_anchor=(0.05,-0.235, 0.6, 0.75),
    bbox_transform=ax1.transAxes,
    loc='center'
)

axins1.plot(df["Temps (s)"], df["t.gran(0cm)"], color='#6904bd')
axins1.plot(df["Temps (s)"], df["t.gran(10cm)"], color='#a237fa')
axins1.plot(df["Temps (s)"], df["t.gran(15cm)"], color='#c37ffa')


# Regió zoom
x1, x2 = 10, 450
y1, y2 = 68, 76
axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)
axins1.set_xticks([])
axins1.set_yticks([])

axins1.text(170, 74.7, '$Δt_1$ (d=10 cm)', fontsize=12)
axins1.text(217, 70.2, '$Δt_2$ (d=15 cm)', fontsize=12)

# Connectar a gràfic principal
mark_inset(ax1, axins1, loc1=2, loc2=3, fc="none", ec="0.5")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2300336831.py in <cell line: 0>()
#       9 ax1.set_title("Evolució de la temperatura a la barra d'alumini gran (∅=5,1 cm)")
#      10 ax1.grid(True)
# ---> 11 ax1.plot(df["Temps (s)"], df["t.gran(0cm)"], label="d=0 cm", color='#6904bd')
#      12 ax1.vlines(90,68,85.7,color='k',linestyle=":")
#      13
#
# NameError: name 'df' is not defined
